# %%
import os
os.chdir('..')  #cd to project folder

import pandas as pd
from Bio import Phylo
import yaml
import numpy as np
from pathlib import Path
import logging
logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')

# %%
#load config
with open('config/lcms.yaml', 'r') as file:
    config = yaml.safe_load(file)

#import Angiosperms tree
tree_file_path = Path('results/phylo_tree/global_tree_brlen_pruned_renamed.tre')
if tree_file_path.exists():
    tree = Phylo.read(tree_file_path, 'newick')
    logging.info(f'Angiosperms phylogenetic tree successfully imported!')
else:
    logging.warning(f'Tree file not found in {tree_file_path}.')

#import scaffold list
scaffold_list = config['scaffolds']

#import cleaned sparql results, concatenate into single df
scaffold_df = []
for scaffold, path in config['sparql_results_clean'].items():
    df = pd.read_csv(path)
    df['Scaffold'] = scaffold
    scaffold_df.append(df)
scaffold_df = pd.concat(scaffold_df, ignore_index=True)
# Out:
# INFO: Angiosperms phylogenetic tree successfully imported!

# %% [markdown]
# Convert phylogenetic tree into data table (`Order`, `Family`, `Genus`, `Species`) and add binary columns for each scaffold (0: not reported in genus; 1:reported in genus)

# %%
#extract leaf names
tree_leaves = [leaf.name for leaf in tree.get_terminals()]
tree_leaves = pd.Series(tree_leaves, name='leaf_name')
logging.info(f'Tree contains {len(tree_leaves)} leaves')
logging.info(f"{tree_leaves.str.endswith('sp.').sum()} species names are not defined in the tree (e.g., 'Lessertia_sp.')")

#create df with order, family, genus, species
tree_df = tree_leaves.str.split('_', expand=True)
tree_df = tree_df.iloc[:, :4] #keep first 4 columns
tree_df.columns = ['Order', 'Family', 'Genus', 'Species']
tree_df = pd.concat([tree_leaves, tree_df], axis=1).rename(columns={0: 'leaf_name'}).set_index('leaf_name')

#add binary column for each scaffold
for s in scaffold_list:
    tree_df[s] = 0  #create zero column
    genera_list = scaffold_df[scaffold_df['Scaffold'] == s]['genus_name'].unique() #list of genera with report (for each scaffold)
    logging.info(f"{s} scaffold reported in {len(genera_list)} genera based on Wikiedata")

    #if genus with report present in the tree, set to 1
    for g in genera_list:
        tree_df.loc[tree_df['Genus'] == g, s] = 1  

#print
tree_df.head(n=5)
# Out:
# INFO: Tree contains 7922 leaves
# INFO: 293 species names are not defined in the tree (e.g., 'Lessertia_sp.')
# INFO: benzylisoquinoline scaffold reported in 293 genera based on Wikiedata
# INFO: aporphine scaffold reported in 191 genera based on Wikiedata
# INFO: piperolactam scaffold reported in 19 genera based on Wikiedata
# INFO: piperidine scaffold reported in 9 genera based on Wikiedata
# INFO: seco-bia scaffold reported in 1 genera based on Wikiedata
#                                      Order   Family         Genus    Species  \
# leaf_name
# Poales_Poaceae_Neostapfia_colusana  Poales  Poaceae    Neostapfia   colusana
# Poales_Poaceae_Orcuttia_tenuis      Poales  Poaceae      Orcuttia     tenuis
# Poales_Poaceae_Orinus_thoroldii     Poales  Poaceae        Orinus  thoroldii
# Poales_Poaceae_Tridentopsis_mutica  Poales  Poaceae  Tridentopsis     mutica
# Poales_Poaceae_Gouinia_latifolia    Poales  Poaceae       Gouinia  latifolia
#
#                                     benzylisoquinoline  aporphine  \
# leaf_name
# Poales_Poaceae_Neostapfia_colusana                   0          0
# Poales_Poaceae_Orcuttia_tenuis                       0          0
# Poales_Poaceae_Orinus_thoroldii                      0          0
# Poales_Poaceae_Tridentopsis_mutica                   0          0
# Poales_Poaceae_Gouinia_latifolia                     0          0
#
#                                     piperolactam  piperidine  seco-bia
# leaf_name
# Poales_Poaceae_Neostapfia_colusana             0           0         0
# Poales_Poaceae_Orcuttia_tenuis                 0           0         0
# Poales_Poaceae_Orinus_thoroldii                0           0         0
# Poales_Poaceae_Tridentopsis_mutica             0           0         0
# Poales_Poaceae_Gouinia_latifolia               0           0         0

# %% [markdown]
# Correct data based on manual inspection

# %%
#manual fixes
tree_df.loc['Piperales_Piperaceae_Piper_nigrum', 'seco-bia'] = 1 #seco-bia scaffold in Piper (present study)
tree_df.loc['Solanales_Solanaceae_Capsicum_annuum', 'piperidine'] = 0 #error in Wikidata for pieperine in Capsicumannuum
tree_df.loc['Asterales_Asteraceae_Centaurea_stoebe', 'piperidine'] = 0 #lack of NMR data for pieperine in Centaurea aegyptica
tree_df.loc['Sapindales_Meliaceae_Aglaia_macrocarpa', 'piperidine'] = 0 #lack of NMR data for pieperine in Aglaia perviridis

# %% [markdown]
# Summary of scaffolds reported in taxa

# %%
scaff_in_orders = tree_df.groupby('Order')[scaffold_list].sum()
scaff_in_orders = scaff_in_orders[scaff_in_orders.sum(axis=1) != 0] #drop rows with no scaffold

# Sort the bar groups by the total count in descending order
scaff_in_orders = scaff_in_orders.loc[scaff_in_orders.sum(axis=1).sort_values(ascending=False).index]

#plot
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white'), sns.set_context("paper", font_scale=2) #style and context
plt.rcParams['font.family'] = 'Arial' #font
colors = sns.color_palette("colorblind", len(scaffold_list)) #color palette

fig, ax = plt.subplots(figsize=(14, 8))
scaff_in_orders.plot(kind='bar', ax=ax, color=colors, width=0.9, edgecolor='black', linewidth=0.5)

ax.set_title('Distribution of scaffolds in Angiosperm orders', fontdict={'fontweight': 'bold', 'fontsize': 18})
ax.set_ylabel('N° of genera', fontsize=16), ax.set_xlabel('') #axis labels
ax.tick_params(axis='x', labelsize=14), ax.tick_params(axis='y', labelsize=12) #tick labels
ax.yaxis.set_ticks_position('left'), ax.yaxis.set_tick_params(width=0.5) #ticks on y axis

#vertical dashed lines to separate bar groups
for i in range(len(scaff_in_orders) - 1):
    ax.axvline(x=i + 0.5, color='black', linestyle='--', linewidth=0.5)

#capitalize the first letter in the legend for only the first 4 items
handles, labels = ax.get_legend_handles_labels()
labels = [label.capitalize() if i < 4 else label for i, label in enumerate(labels)]
legend = ax.legend(handles, labels, fontsize='14', frameon=True, framealpha=1, edgecolor='black')
legend.get_frame().set_linewidth(0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# iTOL annotation file (full tree)

# %%
#create iTOL binary datasets
itol = tree_df[['benzylisoquinoline', 'aporphine', 'piperolactam', 'piperidine', 'seco-bia']] #reorder columns
itol = itol.replace(0, -1) #replace 0 with -1

# Write headers to the iTOL annotation file
output_path = Path('results/phylo_tree/iTOL_scaffolds.txt')
with open(output_path, 'w') as f:
    f.write('DATASET_BINARY\n')
    f.write('SEPARATOR COMMA\n')
    f.write(f'DATASET_LABEL,Scaffold\n') #dataset name
    f.write(f'COLOR,{",".join(["#000000"] * len(itol.columns))}\n') #all black
    f.write(f'FIELD_SHAPES,{",".join([str(i + 1) for i in range(len(itol.columns))])}\n') #shapes from 1 to 5
    f.write(f'FIELD_LABELS,{",".join(itol.columns)}\n') #scaffold names
    f.write('DATA\n')

    # Write each row of the dataframe as a line in the annotation file
    for id, row in itol.iterrows():
        # Convert the row values to strings and join them with commas
        f.write(f'{id},{",".join(map(str, row.values))}\n')
    
    logging.info(f'Annotation file written to {output_path}')
# Out:
# INFO: Annotation file written to results/phylo_tree/iTOL_scaffolds.txt

# %% [markdown]
# Create "smaller" tree

# %%
#copy of the tree
tree_small = tree

#remove nodes from orders with no scaffold
nodes_to_remove = tree_df[~tree_df['Order'].isin(scaff_in_orders.index)].index.to_list()
for n in nodes_to_remove:
    clade = tree_small.find_any(name=n)
    if clade:
        tree_small.prune(clade)
        logging.info(f"{n} leaf removed from tree...")
    else:
        logging.warning(f"{n} leaf not found in the tree.")

# Save the modified tree to a new file
output_path = tree_file_path.with_name('small_tree.newick')
Phylo.write(tree_small, output_path, "newick")
logging.info(f'Small tree saved as in {output_path}')
# Out:
# INFO: Poales_Poaceae_Neostapfia_colusana leaf removed from tree...
# INFO: Poales_Poaceae_Orcuttia_tenuis leaf removed from tree...
# INFO: Poales_Poaceae_Orinus_thoroldii leaf removed from tree...
# INFO: Poales_Poaceae_Tridentopsis_mutica leaf removed from tree...
# INFO: Poales_Poaceae_Gouinia_latifolia leaf removed from tree...
# INFO: Poales_Poaceae_Sphenopholis_obtusata leaf removed from tree...
# INFO: Poales_Poaceae_Triplasiella_eragrostoides leaf removed from tree...
# INFO: Poales_Poaceae_Vaseyochloa_multinervosa leaf removed from tree...
# INFO: Poales_Poaceae_Craspedorhachis_africana leaf removed from tree...
# INFO: Poales_Poaceae_Farrago_racemosa leaf removed from tree...
# INFO: Poales_Poaceae_Perotis_rara leaf removed from tree...
# INFO: Poales_Poaceae_Mosdenia_leptostachys leaf removed from tree...
# INFO: Poales_Poaceae_Trichoneura_grandiglumis leaf removed from tree...
# INFO: Poales_Poaceae_Coleanthus_subtilis leaf removed from tree...
# INFO: Poales_Poaceae_Tetrachaete_elionuroides leaf removed from tree...
# INFO: Poales_Poaceae_Dignathia_gracilis leaf removed from tree...
# INFO: Poales_Poaceae_Hubbardochloa_gracilis leaf removed from tree...
# INFO: Poales_Poaceae_Lophacme_digitata leaf removed from tree...
# INFO: Poales_Poaceae_Lepturidium_insulare leaf removed from tree...
# INFO: Poales_Poaceae_Bewsia_biflora leaf removed from tree...
# INFO: Poales_Poaceae_Leptocarydion_vulpiastrum leaf removed from tree...
# INFO: Poales_Poaceae_Ctenium_concinnum leaf removed from tree...
# INFO: Poales_Poaceae_Zaqiqah_mucronata leaf removed from tree...
# INFO: Poales_Poaceae_Odyssea_paucinervis leaf removed from tree...
# INFO: Poales_Poaceae_Aeluropus_pungens leaf removed from tree...
# INFO: Poales_Poaceae_Cleistogenes_songorica leaf removed from tree...
# INFO: Poales_Poaceae_Lepturus_anadabolavensis leaf removed from tree...
# INFO: Poales_Poaceae_Daknopholis_boivinii leaf removed from tree...
# INFO: Poales_Poaceae_Cynochloris_reynoldsensis leaf removed from tree...
# INFO: Poales_Poaceae_Chloris_truncata leaf removed from tree...
# INFO: Poales_Poaceae_Chrysochloa_hindsii leaf removed from tree...
# INFO: Poales_Poaceae_Cynodon_convergens leaf removed from tree...
# INFO: Poales_Poaceae_Harpochloa_falx leaf removed from tree...
# INFO: Poales_Poaceae_Microchloa_indica leaf removed from tree...
# INFO: Poales_Poaceae_Micrachne_fulva leaf removed from tree...
# INFO: Poales_Poaceae_Oxychloris_scariosa leaf removed from tree...
# INFO: Poales_Poaceae_Enteropogon_acicularis leaf removed from tree...
# INFO: Poales_Poaceae_Astrebla_pectinata leaf removed from tree...
# INFO: Poales_Poaceae_Austrochloris_dichanthioides leaf removed from tree...
# INFO: Poales_Poaceae_Disakisperma_dubium leaf removed from tree...
# INFO: Poales_Poaceae_Eleusine_coracana leaf removed from tree...
# INFO: Poales_Poaceae_Apochiton_burttii leaf removed from tree...
# INFO: Poales_Poaceae_Diplachne_fusca leaf removed from tree...
# INFO: Poales_Poaceae_Pommereulla_cornucopiae leaf removed from tree...
# INFO: Poales_Poaceae_Leptochloa_chinensis leaf removed from tree...
# INFO: Poales_Poaceae_Dinebra_haareri leaf removed from tree...
# INFO: Poales_Poaceae_Brachychloa_fragilis leaf removed from tree...
# INFO: Poales_Poaceae_Acrachne_racemosa leaf removed from tree...
# INFO: Poales_Poaceae_Sclerodactylon_sp. leaf removed from tree...
# INFO: Poales_Poaceae_Dactyloctenium_radulans leaf removed from tree...
# INFO: Poales_Poaceae_Desmostachya_bipinnata leaf removed from tree...
# INFO: Poales_Poaceae_Neobouteloua_lophostachya leaf removed from tree...
# INFO: Poales_Poaceae_Triodia_sp. leaf removed from tree...
# INFO: Poales_Poaceae_Pogononeura_biflora leaf removed from tree...
# INFO: Poales_Poaceae_Monelytrum_luederitzianum leaf removed from tree...
# INFO: Poales_Poaceae_Orthacanthus_pedunculatus leaf removed from tree...
# INFO: Poales_Poaceae_Tragus_berteronianus leaf removed from tree...
# INFO: Poales_Poaceae_Willkommia_texana leaf removed from tree...
# INFO: Poales_Poaceae_Polevansia_rigida leaf removed from tree...
# INFO: Poales_Poaceae_Jouvea_straminea leaf removed from tree...
# INFO: Poales_Poaceae_Blepharidachne_kingii leaf removed from tree...
# INFO: Poales_Poaceae_Erioneuron_avenaceum leaf removed from tree...
# INFO: Poales_Poaceae_Munroa_decumbens leaf removed from tree...
# INFO: Poales_Poaceae_Scleropogon_brevifolius leaf removed from tree...
# INFO: Poales_Poaceae_Swallenia_alexandrae leaf removed from tree...
# INFO: Poales_Poaceae_Bouteloua_dactyloides leaf removed from tree...
# INFO: Poales_Poaceae_Sohnsia_filifolia leaf removed from tree...
# INFO: Poales_Poaceae_Muhlenbergia_arenicola leaf removed from tree...
# INFO: Poales_Poaceae_Kalinia_obtusiflora leaf removed from tree...
# INFO: Poales_Poaceae_Pappophorum_vaginatum leaf removed from tree...
# INFO: Poales_Poaceae_Tridens_brasiliensis leaf removed from tree...
# INFO: Poales_Poaceae_Hilaria_cenchroides leaf removed from tree...
# INFO: Poales_Poaceae_Distichlis_distichophylla leaf removed from tree...
# INFO: Poales_Poaceae_Osvaldoa_valida leaf removed from tree...
# INFO: Poales_Poaceae_Neesiochloa_barbata leaf removed from tree...
# INFO: Poales_Poaceae_Eragrostiella_bifaria leaf removed from tree...
# INFO: Poales_Poaceae_Tripogonella_loliiformis leaf removed from tree...
# INFO: Poales_Poaceae_Oropetium_thomaeum leaf removed from tree...
# INFO: Poales_Poaceae_Halopyrum_mucronatum leaf removed from tree...
# INFO: Poales_Poaceae_Sporobolus_sp. leaf removed from tree...
# INFO: Poales_Poaceae_Eragrostis_australasica leaf removed from tree...
# INFO: Poales_Poaceae_Zoysia_macrantha leaf removed from tree...
# INFO: Poales_Poaceae_Urochondra_setulosa leaf removed from tree...
# INFO: Poales_Poaceae_Afrotrichloris_martinii leaf removed from tree...
# INFO: Poales_Poaceae_Harpachne_schimperi leaf removed from tree...
# INFO: Poales_Poaceae_Ectrosia_agrostoides leaf removed from tree...
# INFO: Poales_Poaceae_Heterachne_gulliveri leaf removed from tree...
# INFO: Poales_Poaceae_Steirachne_barbata leaf removed from tree...
# INFO: Poales_Poaceae_Catalepis_gracilis leaf removed from tree...
# INFO: Poales_Poaceae_Stiburus_conrathii leaf removed from tree...
# INFO: Poales_Poaceae_Cladoraphis_spinosa leaf removed from tree...
# INFO: Poales_Poaceae_Fingerhuthia_africana leaf removed from tree...
# INFO: Poales_Poaceae_Entoplocamia_aristulata leaf removed from tree...
# INFO: Poales_Poaceae_Tetrachne_dregei leaf removed from tree...
# INFO: Poales_Poaceae_Uniola_paniculata leaf removed from tree...
# INFO: Poales_Poaceae_Schmidtia_pappophoroides leaf removed from tree...
# INFO: Poales_Poaceae_Enneapogon_cylindricus leaf removed from tree...
# INFO: Poales_Poaceae_Neyraudia_reynaudiana leaf removed from tree...
# INFO: Poales_Poaceae_Habrochloa_bullockii leaf removed from tree...
# INFO: Poales_Poaceae_Triraphis_mollis leaf removed from tree...
# INFO: Poales_Poaceae_Ellisochloa_rangei leaf removed from tree...
# INFO: Poales_Poaceae_Centropodia_glauca leaf removed from tree...
# INFO: Poales_Poaceae_Chionochloa_macra leaf removed from tree...
# INFO: Poales_Poaceae_Austroderia_richardii leaf removed from tree...
# INFO: Poales_Poaceae_Rytidosperma_erianthum leaf removed from tree...
# INFO: Poales_Poaceae_Schismus_barbatus leaf removed from tree...
# INFO: Poales_Poaceae_Phaenanthoecium_koestlinii leaf removed from tree...
# INFO: Poales_Poaceae_Plinthanthesis_paradoxa leaf removed from tree...
# INFO: Poales_Poaceae_Notochloe_microdon leaf removed from tree...
# INFO: Poales_Poaceae_Danthonia_intermedia leaf removed from tree...
# INFO: Poales_Poaceae_Cortaderia_jubata leaf removed from tree...
# INFO: Poales_Poaceae_Capeochloa_cincta leaf removed from tree...
# INFO: Poales_Poaceae_Chimaerochloa_archboldii leaf removed from tree...
# INFO: Poales_Poaceae_Monachather_paradoxus leaf removed from tree...
# INFO: Poales_Poaceae_Molinia_caerulea leaf removed from tree...
# INFO: Poales_Poaceae_Arundo_donax leaf removed from tree...
# INFO: Poales_Poaceae_Hakonechloa_macra leaf removed from tree...
# INFO: Poales_Poaceae_Moliniopsis_japonica leaf removed from tree...
# INFO: Poales_Poaceae_Phragmites_australis leaf removed from tree...
# INFO: Poales_Poaceae_Pratochloa_walteri leaf removed from tree...
# INFO: Poales_Poaceae_Elytrophorus_spicatus leaf removed from tree...
# INFO: Poales_Poaceae_Amphipogon_strictus leaf removed from tree...
# INFO: Poales_Poaceae_Stipagrostis_uniplumis leaf removed from tree...
# INFO: Poales_Poaceae_Merostachys_annulifera leaf removed from tree...
# INFO: Poales_Poaceae_Sartidia_angolensis leaf removed from tree...
# INFO: Poales_Poaceae_Aristida_adscensionis leaf removed from tree...
# INFO: Poales_Poaceae_Limnopoa_meeboldii leaf removed from tree...
# INFO: Poales_Poaceae_Isachne_globosa leaf removed from tree...
# INFO: Poales_Poaceae_Hubbardia_heptaneuron leaf removed from tree...
# INFO: Poales_Poaceae_Sphaerocaryum_malaccense leaf removed from tree...
# INFO: Poales_Poaceae_Coelachne_pulchella leaf removed from tree...
# INFO: Poales_Poaceae_Heteranthoecia_guineensis leaf removed from tree...
# INFO: Poales_Poaceae_Eriachne_mucronata leaf removed from tree...
# INFO: Poales_Poaceae_Pheidochloa_gracilis leaf removed from tree...
# INFO: Poales_Poaceae_Micraira_subulifolia leaf removed from tree...
# INFO: Poales_Poaceae_Tylorhiza_setifolia leaf removed from tree...
# INFO: Poales_Poaceae_Danthonidium_gammiei leaf removed from tree...
# INFO: Poales_Poaceae_Trilobachne_cookei leaf removed from tree...
# INFO: Poales_Poaceae_Polytoca_cyathopoda leaf removed from tree...
# INFO: Poales_Poaceae_Pogonatherum_rufobarbatum leaf removed from tree...
# INFO: Poales_Poaceae_Imperata_cylindrica leaf removed from tree...
# INFO: Poales_Poaceae_Apocopis_intermedius leaf removed from tree...
# INFO: Poales_Poaceae_Germainia_truncatiglumis leaf removed from tree...
# INFO: Poales_Poaceae_Saccharum_spontaneum leaf removed from tree...
# INFO: Poales_Poaceae_Narenga_porphyrocoma leaf removed from tree...
# INFO: Poales_Poaceae_Miscanthus_fuscus leaf removed from tree...
# INFO: Poales_Poaceae_Miscanthidium_violaceum leaf removed from tree...
# INFO: Poales_Poaceae_Tripidium_strictum leaf removed from tree...
# INFO: Poales_Poaceae_Sarga_plumosa leaf removed from tree...
# INFO: Poales_Poaceae_Cleistachne_sorghoides leaf removed from tree...
# INFO: Poales_Poaceae_Sorghum_macrospermum leaf removed from tree...
# INFO: Poales_Poaceae_Agenium_leptocladum leaf removed from tree...
# INFO: Poales_Poaceae_Spathia_neurosa leaf removed from tree...
# INFO: Poales_Poaceae_Dichanthium_sericeum leaf removed from tree...
# INFO: Poales_Poaceae_Euclasta_condylotricha leaf removed from tree...
# INFO: Poales_Poaceae_Bothriochloa_ischaemum leaf removed from tree...
# INFO: Poales_Poaceae_Capillipedium_parviflorum leaf removed from tree...
# INFO: Poales_Poaceae_Iseilema_membranaceum leaf removed from tree...
# INFO: Poales_Poaceae_Heteropogon_contortus leaf removed from tree...
# INFO: Poales_Poaceae_Themeda_triandra leaf removed from tree...
# INFO: Poales_Poaceae_Andropogon_virginicus leaf removed from tree...
# INFO: Poales_Poaceae_Parahyparrhenia_annua leaf removed from tree...
# INFO: Poales_Poaceae_Schizachyrium_fragile leaf removed from tree...
# INFO: Poales_Poaceae_Anadelphia_leptocoma leaf removed from tree...
# INFO: Poales_Poaceae_Hyparrhenia_hirta leaf removed from tree...
# INFO: Poales_Poaceae_Cymbopogon_nardus leaf removed from tree...
# INFO: Poales_Poaceae_Spodiopogon_dubius leaf removed from tree...
# INFO: Poales_Poaceae_Asthenochloa_tenera leaf removed from tree...
# INFO: Poales_Poaceae_Pseudodichanthium_serrafalcoides leaf removed from tree...
# INFO: Poales_Poaceae_Rottboellia_cochinchinensis leaf removed from tree...
# INFO: Poales_Poaceae_Phacelurus_speciosus leaf removed from tree...
# INFO: Poales_Poaceae_Coix_lacryma-jobi leaf removed from tree...
# INFO: Poales_Poaceae_Eulaliopsis_sykesii leaf removed from tree...
# INFO: Poales_Poaceae_Andropterum_stolzii leaf removed from tree...
# INFO: Poales_Poaceae_Trachypogon_spicatus leaf removed from tree...
# INFO: Poales_Poaceae_Homozeugos_eylesii leaf removed from tree...
# INFO: Poales_Poaceae_Apluda_mutica leaf removed from tree...
# INFO: Poales_Poaceae_Sehima_galpinii leaf removed from tree...
# INFO: Poales_Poaceae_Eulalia_aurea leaf removed from tree...
# INFO: Poales_Poaceae_Dimeria_ornithopoda leaf removed from tree...
# INFO: Poales_Poaceae_Bhidea_fischeri leaf removed from tree...
# INFO: Poales_Poaceae_Ischaemum_muticum leaf removed from tree...
# INFO: Poales_Poaceae_Polytrias_indica leaf removed from tree...
# INFO: Poales_Poaceae_Microstegium_vimineum leaf removed from tree...
# INFO: Poales_Poaceae_Loxodera_strigosa leaf removed from tree...
# INFO: Poales_Poaceae_Eriochrysis_holcoides leaf removed from tree...
# INFO: Poales_Poaceae_Erianthus_asper leaf removed from tree...
# INFO: Poales_Poaceae_Hemarthria_protensa leaf removed from tree...
# INFO: Poales_Poaceae_Pseudopogonatherum_contortum leaf removed from tree...
# INFO: Poales_Poaceae_Pogonachne_racemosa leaf removed from tree...
# INFO: Poales_Poaceae_Chrysopogon_aciculatus leaf removed from tree...
# INFO: Poales_Poaceae_Arundinella_bengalensis leaf removed from tree...
# INFO: Poales_Poaceae_Clausospicula_extensa leaf removed from tree...
# INFO: Poales_Poaceae_Thaumastochloa_monilifera leaf removed from tree...
# INFO: Poales_Poaceae_Eremochloa_ophiuroides leaf removed from tree...
# INFO: Poales_Poaceae_Ophiuros_exaltatus leaf removed from tree...
# INFO: Poales_Poaceae_Heteropholis_nigrescens leaf removed from tree...
# INFO: Poales_Poaceae_Manisuris_myurus leaf removed from tree...
# INFO: Poales_Poaceae_Hackelochloa_granularis leaf removed from tree...
# INFO: Poales_Poaceae_Elionurus_citreus leaf removed from tree...
# INFO: Poales_Poaceae_Oxyrhachis_gracillima leaf removed from tree...
# INFO: Poales_Poaceae_Rhytachne_megastachya leaf removed from tree...
# INFO: Poales_Poaceae_Zea_diploperennis leaf removed from tree...
# INFO: Poales_Poaceae_Tripsacum_dactyloides leaf removed from tree...
# INFO: Poales_Poaceae_Chasmopodium_caudatum leaf removed from tree...
# INFO: Poales_Poaceae_Arthraxon_australiensis leaf removed from tree...
# INFO: Poales_Poaceae_Garnotia_stricta leaf removed from tree...
# INFO: Poales_Poaceae_Ocellochloa_stolonifera leaf removed from tree...
# INFO: Poales_Poaceae_Oedochloa_minarum leaf removed from tree...
# INFO: Poales_Poaceae_Ichnanthus_pallens leaf removed from tree...
# INFO: Poales_Poaceae_Oplismenopsis_najada leaf removed from tree...
# INFO: Poales_Poaceae_Renvoizea_sacciolepoides leaf removed from tree...
# INFO: Poales_Poaceae_Gerritea_pseudopetiolata leaf removed from tree...
# INFO: Poales_Poaceae_Chaetium_festucoides leaf removed from tree...
# INFO: Poales_Poaceae_Streptostachys_asperifolia leaf removed from tree...
# INFO: Poales_Poaceae_Axonopus_longispicus leaf removed from tree...
# INFO: Poales_Poaceae_Aakia_tuerckheimii leaf removed from tree...
# INFO: Poales_Poaceae_Anthaenantiopsis_rojasiana leaf removed from tree...
# INFO: Poales_Poaceae_Paspalum_distichum leaf removed from tree...
# INFO: Poales_Poaceae_Hopia_obtusa leaf removed from tree...
# INFO: Poales_Poaceae_Apochloa_poliophylla leaf removed from tree...
# INFO: Poales_Poaceae_Canastra_lanceolata leaf removed from tree...
# INFO: Poales_Poaceae_Triscenia_ovina leaf removed from tree...
# INFO: Poales_Poaceae_Coleataenia_prionitis leaf removed from tree...
# INFO: Poales_Poaceae_Echinolaena_inflexa leaf removed from tree...
# INFO: Poales_Poaceae_Cyphonanthus_discrepans leaf removed from tree...
# INFO: Poales_Poaceae_Oncorachis_ramosa leaf removed from tree...
# INFO: Poales_Poaceae_Anthenantia_lanata leaf removed from tree...
# INFO: Poales_Poaceae_Rugoloa_hylaeica leaf removed from tree...
# INFO: Poales_Poaceae_Hymenachne_felliana leaf removed from tree...
# INFO: Poales_Poaceae_Steinchisma_decipiens leaf removed from tree...
# INFO: Poales_Poaceae_Tatianyx_arnacites leaf removed from tree...
# INFO: Poales_Poaceae_Mesosetum_comatum leaf removed from tree...
# INFO: Poales_Poaceae_Keratochlaena_rigidifolia leaf removed from tree...
# INFO: Poales_Poaceae_Altoparadisium_chapadense leaf removed from tree...
# INFO: Poales_Poaceae_Arthropogon_piptostachyus leaf removed from tree...
# INFO: Poales_Poaceae_Homolepis_villaricensis leaf removed from tree...
# INFO: Poales_Poaceae_Reynaudia_filiformis leaf removed from tree...
# INFO: Poales_Poaceae_Poecilostachys_geminata leaf removed from tree...
# INFO: Poales_Poaceae_Oplismenus_burmanni leaf removed from tree...
# INFO: Poales_Poaceae_Streptolophus_sagittifolius leaf removed from tree...
# INFO: Poales_Poaceae_Setariopsis_latiglumis leaf removed from tree...
# INFO: Poales_Poaceae_Uranthoecium_truncatum leaf removed from tree...
# INFO: Poales_Poaceae_Stenotaphrum_micranthum leaf removed from tree...
# INFO: Poales_Poaceae_Hylebates_chlorochloe leaf removed from tree...
# INFO: Poales_Poaceae_Arthragrostis_brassiana leaf removed from tree...
# INFO: Poales_Poaceae_Panicum_australiense leaf removed from tree...
# INFO: Poales_Poaceae_Louisiella_elephantipes leaf removed from tree...
# INFO: Poales_Poaceae_Digitaria_ternata leaf removed from tree...
# INFO: Poales_Poaceae_Anthephora_hermaphrodita leaf removed from tree...
# INFO: Poales_Poaceae_Tarigidia_aequiglumis leaf removed from tree...
# INFO: Poales_Poaceae_Stereochlaena_caespitosa leaf removed from tree...
# INFO: Poales_Poaceae_Chlorocalymma_cryptacanthum leaf removed from tree...
# INFO: Poales_Poaceae_Taeniorhachis_repens leaf removed from tree...
# INFO: Poales_Poaceae_Chaetopoa_taylorii leaf removed from tree...
# INFO: Poales_Poaceae_Thyridolepis_multiculmis leaf removed from tree...
# INFO: Poales_Poaceae_Neurachne_munroi leaf removed from tree...
# INFO: Poales_Poaceae_Cleistochloa_subjuncea leaf removed from tree...
# INFO: Poales_Poaceae_Ancistrachne_maidenii leaf removed from tree...
# INFO: Poales_Poaceae_Calyptochloa_cylindrosperma leaf removed from tree...
# INFO: Poales_Poaceae_Thyridachne_tisserantii leaf removed from tree...
# INFO: Poales_Poaceae_Sacciolepis_indica leaf removed from tree...
# INFO: Poales_Poaceae_Hydrothauma_manicatum leaf removed from tree...
# INFO: Poales_Poaceae_Trichanthecium_brazzavillense leaf removed from tree...
# INFO: Poales_Poaceae_Kellochloa_verrucosa leaf removed from tree...
# INFO: Poales_Poaceae_Homopholis_belsonii leaf removed from tree...
# INFO: Poales_Poaceae_Walwhalleya_subxerophila leaf removed from tree...
# INFO: Poales_Poaceae_Acritochaete_volkensii leaf removed from tree...
# INFO: Poales_Poaceae_Microcalamus_barbinodis leaf removed from tree...
# INFO: Poales_Poaceae_Danthoniopsis_dinteri leaf removed from tree...
# INFO: Poales_Poaceae_Tristachya_superba leaf removed from tree...
# INFO: Poales_Poaceae_Gilgiochloa_indurata leaf removed from tree...
# INFO: Poales_Poaceae_Neostapfiella_perrieri leaf removed from tree...
# INFO: Poales_Poaceae_Zonotriche_decora leaf removed from tree...
# INFO: Poales_Poaceae_Trichopteryx_sp. leaf removed from tree...
# INFO: Poales_Poaceae_Dilophotriche_occidentalis leaf removed from tree...
# INFO: Poales_Poaceae_Loudetiopsis_kerstingii leaf removed from tree...
# INFO: Poales_Poaceae_Loudetia_simplex leaf removed from tree...
# INFO: Poales_Poaceae_Gynerium_sagittatum leaf removed from tree...
# INFO: Poales_Poaceae_Chasmanthium_latifolium leaf removed from tree...
# INFO: Poales_Poaceae_Spartochloa_scirpoidea leaf removed from tree...
# INFO: Poales_Poaceae_Centotheca_lappacea leaf removed from tree...
# INFO: Poales_Poaceae_Megastachya_mucronata leaf removed from tree...
# INFO: Poales_Poaceae_Thysanolaena_latifolia leaf removed from tree...
# INFO: Poales_Poaceae_Arundoclaytonia_dissimilis leaf removed from tree...
# INFO: Poales_Poaceae_Zeugites_pittieri leaf removed from tree...
# INFO: Poales_Poaceae_Lophatherum_sinense leaf removed from tree...
# INFO: Poales_Poaceae_Orthoclada_africana leaf removed from tree...
# INFO: Poales_Poaceae_Ratzeburgia_pulcherrima leaf removed from tree...
# INFO: Poales_Poaceae_Styppeiochloa_hitchcockii leaf removed from tree...
# INFO: Poales_Poaceae_Alloeochaete_gracillima leaf removed from tree...
# INFO: Poales_Poaceae_Dichaetaria_wightii leaf removed from tree...
# INFO: Poales_Poaceae_Gaudinia_fragilis leaf removed from tree...
# INFO: Poales_Poaceae_Avellinia_festucoides leaf removed from tree...
# INFO: Poales_Poaceae_Trisetaria_chaudharyana leaf removed from tree...
# INFO: Poales_Poaceae_Rostraria_cristata leaf removed from tree...
# INFO: Poales_Poaceae_Trisetum_spicatum leaf removed from tree...
# INFO: Poales_Poaceae_Acrospelion_distichophyllum leaf removed from tree...
# INFO: Poales_Poaceae_Koeleria_macrantha leaf removed from tree...
# INFO: Poales_Poaceae_Tzveleviochloa_burmanica leaf removed from tree...
# INFO: Poales_Poaceae_Helictotrichon_filifolium leaf removed from tree...
# INFO: Poales_Poaceae_Tricholemma_jahandiezii leaf removed from tree...
# INFO: Poales_Poaceae_Cinnagrostis_sp. leaf removed from tree...
# INFO: Poales_Poaceae_Pentapogon_quadrifidus leaf removed from tree...
# INFO: Poales_Poaceae_Avena_fatua leaf removed from tree...
# INFO: Poales_Poaceae_Phalaris_aquatica leaf removed from tree...
# INFO: Poales_Poaceae_Oreochloa_elegans leaf removed from tree...
# INFO: Poales_Poaceae_Sesleriella_sphaerocephala leaf removed from tree...
# INFO: Poales_Poaceae_Echinopogon_ovatus leaf removed from tree...
# INFO: Poales_Poaceae_Dichelachne_crinita leaf removed from tree...
# INFO: Poales_Poaceae_Vahlodea_atropurpurea leaf removed from tree...
# INFO: Poales_Poaceae_Polypogon_tenellus leaf removed from tree...
# INFO: Poales_Poaceae_Lachnagrostis_aemula leaf removed from tree...
# INFO: Poales_Poaceae_Agrostis_hygrometrica leaf removed from tree...
# INFO: Poales_Poaceae_Podagrostis_colombiana leaf removed from tree...
# INFO: Poales_Poaceae_Calamagrostis_tripilifera leaf removed from tree...
# INFO: Poales_Poaceae_Relchela_panicoides leaf removed from tree...
# INFO: Poales_Poaceae_Hypseochloa_cameroonensis leaf removed from tree...
# INFO: Poales_Poaceae_Amphibromus_neesii leaf removed from tree...
# INFO: Poales_Poaceae_Avenella_flexuosa leaf removed from tree...
# INFO: Poales_Poaceae_Corynephorus_fasciculatus leaf removed from tree...
# INFO: Poales_Poaceae_Echinaria_capitata leaf removed from tree...
# INFO: Poales_Poaceae_Holcus_lanatus leaf removed from tree...
# INFO: Poales_Poaceae_Anthoxanthum_odoratum leaf removed from tree...
# INFO: Poales_Poaceae_Limnas_veresczaginii leaf removed from tree...
# INFO: Poales_Poaceae_Briza_humilis leaf removed from tree...
# INFO: Poales_Poaceae_Alopecurus_aequalis leaf removed from tree...
# INFO: Poales_Poaceae_Apera_spica-venti leaf removed from tree...
# INFO: Poales_Poaceae_Rhizocephalus_orientalis leaf removed from tree...
# INFO: Poales_Poaceae_Cornucopiae_cucullatum leaf removed from tree...
# INFO: Poales_Poaceae_Ventenata_dubia leaf removed from tree...
# INFO: Poales_Poaceae_Nephelochloa_orientalis leaf removed from tree...
# INFO: Poales_Poaceae_Pholiurus_pannonicus leaf removed from tree...
# INFO: Poales_Poaceae_Beckmannia_syzigachne leaf removed from tree...
# INFO: Poales_Poaceae_Paracolpodium_wallichii leaf removed from tree...
# INFO: Poales_Poaceae_Colpodium_hedbergii leaf removed from tree...
# INFO: Poales_Poaceae_Puccinellia_perlaxa leaf removed from tree...
# INFO: Poales_Poaceae_Phippsia_algida leaf removed from tree...
# INFO: Poales_Poaceae_Hyalopoa_pontica leaf removed from tree...
# INFO: Poales_Poaceae_Catabrosella_variegata leaf removed from tree...
# INFO: Poales_Poaceae_Cyathopus_sikkimensis leaf removed from tree...
# INFO: Poales_Poaceae_Poa_annua leaf removed from tree...
# INFO: Poales_Poaceae_Agrostopoa_woodii leaf removed from tree...
# INFO: Poales_Poaceae_Phleum_pratense leaf removed from tree...
# INFO: Poales_Poaceae_Dupontia_fulva leaf removed from tree...
# INFO: Poales_Poaceae_Arctopoa_eminens leaf removed from tree...
# INFO: Poales_Poaceae_Nicoraepoa_subenervis leaf removed from tree...
# INFO: Poales_Poaceae_Sylvipoa_queenslandica leaf removed from tree...
# INFO: Poales_Poaceae_Hookerochloa_hookeriana leaf removed from tree...
# INFO: Poales_Poaceae_Cinna_poiformis leaf removed from tree...
# INFO: Poales_Poaceae_Deschampsia_cespitosa leaf removed from tree...
# INFO: Poales_Poaceae_Cynosurus_cristatus leaf removed from tree...
# INFO: Poales_Poaceae_Sphenopus_divaricatus leaf removed from tree...
# INFO: Poales_Poaceae_Vulpiella_stipoides leaf removed from tree...
# INFO: Poales_Poaceae_Parapholis_cylindrica leaf removed from tree...
# INFO: Poales_Poaceae_Agropyropsis_lolium leaf removed from tree...
# INFO: Poales_Poaceae_Dactylis_glomerata leaf removed from tree...
# INFO: Poales_Poaceae_Lolium_multiflorum leaf removed from tree...
# INFO: Poales_Poaceae_Festuca_muelleri leaf removed from tree...
# INFO: Poales_Poaceae_Pseudobromus_ambilobensis leaf removed from tree...
# INFO: Poales_Poaceae_Molineriella_minuta leaf removed from tree...
# INFO: Poales_Poaceae_Scolochloa_festucacea leaf removed from tree...
# INFO: Poales_Poaceae_Dryopoa_dives leaf removed from tree...
# INFO: Poales_Poaceae_Bellardiochloa_variegata leaf removed from tree...
# INFO: Poales_Poaceae_Pseudophleum_gibbum leaf removed from tree...
# INFO: Poales_Poaceae_Dupontiopsis_hayachinensis leaf removed from tree...
# INFO: Poales_Poaceae_Saxipoa_saxicola leaf removed from tree...
# INFO: Poales_Poaceae_Peyritschia_deyeuxioides leaf removed from tree...
# INFO: Poales_Poaceae_Ancistragrostis_uncinioides leaf removed from tree...
# INFO: Poales_Poaceae_Henrardia_persica leaf removed from tree...
# INFO: Poales_Poaceae_Agropyron_cristatum leaf removed from tree...
# INFO: Poales_Poaceae_Stenostachys_laevis leaf removed from tree...
# INFO: Poales_Poaceae_Eremopyrum_bonaepartis leaf removed from tree...
# INFO: Poales_Poaceae_Triticum_aestivum leaf removed from tree...
# INFO: Poales_Poaceae_Aegilops_tauschii leaf removed from tree...
# INFO: Poales_Poaceae_Taeniatherum_caput-medusae leaf removed from tree...
# INFO: Poales_Poaceae_Thinopyrum_intermedium leaf removed from tree...
# INFO: Poales_Poaceae_Hordeum_vulgare leaf removed from tree...
# INFO: Poales_Poaceae_Elymus_sibiricus leaf removed from tree...
# INFO: Poales_Poaceae_Festucopsis_serpentini leaf removed from tree...
# INFO: Poales_Poaceae_Anthosachne_scabra leaf removed from tree...
# INFO: Poales_Poaceae_Australopyrum_pectinatum leaf removed from tree...
# INFO: Poales_Poaceae_Triplasis_purpurea leaf removed from tree...
# INFO: Poales_Poaceae_Pseudoroegneria_spicata leaf removed from tree...
# INFO: Poales_Poaceae_Leymus_mollis leaf removed from tree...
# INFO: Poales_Poaceae_Psathyrostachys_juncea leaf removed from tree...
# INFO: Poales_Poaceae_Heteranthelium_piliferum leaf removed from tree...
# INFO: Poales_Poaceae_Dasypyrum_villosum leaf removed from tree...
# INFO: Poales_Poaceae_Littledalea_przevalskyi leaf removed from tree...
# INFO: Poales_Poaceae_Brachypodium_distachyon leaf removed from tree...
# INFO: Poales_Poaceae_Diarrhena_fauriei leaf removed from tree...
# INFO: Poales_Poaceae_Amelichloa_ambigua leaf removed from tree...
# INFO: Poales_Poaceae_Nassella_mucronata leaf removed from tree...
# INFO: Poales_Poaceae_Jarava_ichu leaf removed from tree...
# INFO: Poales_Poaceae_Oloptum_miliaceum leaf removed from tree...
# INFO: Poales_Poaceae_Eriocoma_hymenoides leaf removed from tree...
# INFO: Poales_Poaceae_Stipellula_capensis leaf removed from tree...
# INFO: Poales_Poaceae_Austrostipa_campylachne leaf removed from tree...
# INFO: Poales_Poaceae_Achnatherum_sibiricum leaf removed from tree...
# INFO: Poales_Poaceae_Timouria_saposhnikowii leaf removed from tree...
# INFO: Poales_Poaceae_Celtica_gigantea leaf removed from tree...
# INFO: Poales_Poaceae_Pappostipa_atacamensis leaf removed from tree...
# INFO: Poales_Poaceae_Hesperostipa_comata leaf removed from tree...
# INFO: Poales_Poaceae_Neotrinia_splendens leaf removed from tree...
# INFO: Poales_Poaceae_Psammochloa_villosa leaf removed from tree...
# INFO: Poales_Poaceae_Ortachne_rariflora leaf removed from tree...
# INFO: Poales_Poaceae_Lorenzochloa_erectifolia leaf removed from tree...
# INFO: Poales_Poaceae_Piptatheropsis_pungens leaf removed from tree...
# INFO: Poales_Poaceae_Orthoraphium_roylei leaf removed from tree...
# INFO: Poales_Poaceae_Ptilagrostis_concinna leaf removed from tree...
# INFO: Poales_Poaceae_Stipa_grandis leaf removed from tree...
# INFO: Poales_Poaceae_Macrochloa_tenacissima leaf removed from tree...
# INFO: Poales_Poaceae_Ampelodesmos_mauritanicus leaf removed from tree...
# INFO: Poales_Poaceae_Trikeraia_hookeri leaf removed from tree...
# INFO: Poales_Poaceae_Anisopogon_avenaceus leaf removed from tree...
# INFO: Poales_Poaceae_Duthiea_bromoides leaf removed from tree...
# INFO: Poales_Poaceae_Metcalfia_mexicana leaf removed from tree...
# INFO: Poales_Poaceae_Stephanachne_nigrescens leaf removed from tree...
# INFO: Poales_Poaceae_Pappagrostis_pappophorea leaf removed from tree...
# INFO: Poales_Poaceae_Pseudodanthonia_himalaica leaf removed from tree...
# INFO: Poales_Poaceae_Brylkinia_caudata leaf removed from tree...
# INFO: Poales_Poaceae_Melica_nutans leaf removed from tree...
# INFO: Poales_Poaceae_Lycochloa_avenacea leaf removed from tree...
# INFO: Poales_Poaceae_Koordersiochloa_longiarista leaf removed from tree...
# INFO: Poales_Poaceae_Triniochloa_stipoides leaf removed from tree...
# INFO: Poales_Poaceae_Glyceria_acutiflora leaf removed from tree...
# INFO: Poales_Poaceae_Pleuropogon_sabinei leaf removed from tree...
# INFO: Poales_Poaceae_Nardus_stricta leaf removed from tree...
# INFO: Poales_Poaceae_Lygeum_spartum leaf removed from tree...
# INFO: Poales_Poaceae_Brachyelytrum_erectum leaf removed from tree...
# INFO: Poales_Poaceae_Soejatmia_ridleyi leaf removed from tree...
# INFO: Poales_Poaceae_Thyrsostachys_oliveri leaf removed from tree...
# INFO: Poales_Poaceae_Dendrocalamus_sinicus leaf removed from tree...
# INFO: Poales_Poaceae_Gigantochloa_atter leaf removed from tree...
# INFO: Poales_Poaceae_Bambusa_arnhemica leaf removed from tree...
# INFO: Poales_Poaceae_Dinochloa_orenuda leaf removed from tree...
# INFO: Poales_Poaceae_Maclurochloa_montana leaf removed from tree...
# INFO: Poales_Poaceae_Oxytenanthera_abyssinica leaf removed from tree...
# INFO: Poales_Poaceae_Pseudoxytenanthera_monadelpha leaf removed from tree...
# INFO: Poales_Poaceae_Bonia_saxatilis leaf removed from tree...
# INFO: Poales_Poaceae_Laobambos_calcareus leaf removed from tree...
# INFO: Poales_Poaceae_Phuphanochloa_speciosa leaf removed from tree...
# INFO: Poales_Poaceae_Vietnamosasa_pusilla leaf removed from tree...
# INFO: Poales_Poaceae_Melocalamus_yunnanensis leaf removed from tree...
# INFO: Poales_Poaceae_Oreobambos_buchwaldii leaf removed from tree...
# INFO: Poales_Poaceae_Temochloa_liliana leaf removed from tree...
# INFO: Poales_Poaceae_Kinabaluchloa_nebulosa leaf removed from tree...
# INFO: Poales_Poaceae_Holttumochloa_hainanensis leaf removed from tree...
# INFO: Poales_Poaceae_Neomicrocalamus_prainii leaf removed from tree...
# INFO: Poales_Poaceae_Schizostachyum_pergracile leaf removed from tree...
# INFO: Poales_Poaceae_Melocanna_humilis leaf removed from tree...
# INFO: Poales_Poaceae_Cephalostachyum_capitatum leaf removed from tree...
# INFO: Poales_Poaceae_Neohouzeaua_fimbriata leaf removed from tree...
# INFO: Poales_Poaceae_Ochlandra_stridula leaf removed from tree...
# INFO: Poales_Poaceae_Davidsea_attenuata leaf removed from tree...
# INFO: Poales_Poaceae_Pseudostachyum_polymorphum leaf removed from tree...
# INFO: Poales_Poaceae_Pinga_marginata leaf removed from tree...
# INFO: Poales_Poaceae_Neololeba_atra leaf removed from tree...
# INFO: Poales_Poaceae_Sphaerobambos_hirsuta leaf removed from tree...
# INFO: Poales_Poaceae_Cyrtochloa_toppingii leaf removed from tree...
# INFO: Poales_Poaceae_Mullerochloa_moreheadiana leaf removed from tree...
# INFO: Poales_Poaceae_Parabambusa_kaini leaf removed from tree...
# INFO: Poales_Poaceae_Greslania_circinata leaf removed from tree...
# INFO: Poales_Poaceae_Widjajachloa_producta leaf removed from tree...
# INFO: Poales_Poaceae_Racemobambos_gibbsiae leaf removed from tree...
# INFO: Poales_Poaceae_Ruhooglandia_hooglandii leaf removed from tree...
# INFO: Poales_Poaceae_Chloothamnus_elatus leaf removed from tree...
# INFO: Poales_Poaceae_Olyra_loretensis leaf removed from tree...
# INFO: Poales_Poaceae_Nastus_aristatus leaf removed from tree...
# INFO: Poales_Poaceae_Hickelia_perrieri leaf removed from tree...
# INFO: Poales_Poaceae_Decaryochloa_diadelpha leaf removed from tree...
# INFO: Poales_Poaceae_Valiha_diffusa leaf removed from tree...
# INFO: Poales_Poaceae_Cambajuva_ulei leaf removed from tree...
# INFO: Poales_Poaceae_Cathariostachys_madagascariensis leaf removed from tree...
# INFO: Poales_Poaceae_Sirochloa_parvifolia leaf removed from tree...
# INFO: Poales_Poaceae_Sokinochloa_bosseri leaf removed from tree...
# INFO: Poales_Poaceae_Fimbribambusa_horsfieldii leaf removed from tree...
# INFO: Poales_Poaceae_Temburongia_simplex leaf removed from tree...
# INFO: Poales_Poaceae_Raddiella_kaieteurana leaf removed from tree...
# INFO: Poales_Poaceae_Athroostachys_capitata leaf removed from tree...
# INFO: Poales_Poaceae_Actinocladum_verticillatum leaf removed from tree...
# INFO: Poales_Poaceae_Aulonemia_aristulata leaf removed from tree...
# INFO: Poales_Poaceae_Didymogonyx_geminatum leaf removed from tree...
# INFO: Poales_Poaceae_Arthrostylidium_sp. leaf removed from tree...
# INFO: Poales_Poaceae_Rhipidocladum_racemiflorum leaf removed from tree...
# INFO: Poales_Poaceae_Atractantha_falcata leaf removed from tree...
# INFO: Poales_Poaceae_Alvimia_lancifolia leaf removed from tree...
# INFO: Poales_Poaceae_Filgueirasia_cannavieira leaf removed from tree...
# INFO: Poales_Poaceae_Elytrostachys_clavigera leaf removed from tree...
# INFO: Poales_Poaceae_Colanthelia_rhizantha leaf removed from tree...
# INFO: Poales_Poaceae_Pseudobambusa_schizostachyoides leaf removed from tree...
# INFO: Poales_Poaceae_Apoclada_simplex leaf removed from tree...
# INFO: Poales_Poaceae_Eremocaulon_aureofimbriatum leaf removed from tree...
# INFO: Poales_Poaceae_Guadua_angustifolia leaf removed from tree...
# INFO: Poales_Poaceae_Otatea_glauca leaf removed from tree...
# INFO: Poales_Poaceae_Chusquea_simpliciflora leaf removed from tree...
# INFO: Poales_Poaceae_Himalayacalamus_planatus leaf removed from tree...
# INFO: Poales_Poaceae_Myriocladus_exsertus leaf removed from tree...
# INFO: Poales_Poaceae_Ampelocalamus_luodianensis leaf removed from tree...
# INFO: Poales_Poaceae_Hsuehochloa_calcarea leaf removed from tree...
# INFO: Poales_Poaceae_Gaoligongshania_megalothyrsa leaf removed from tree...
# INFO: Poales_Poaceae_Pseudosasa_japonica leaf removed from tree...
# INFO: Poales_Poaceae_Acidosasa_purpurea leaf removed from tree...
# INFO: Poales_Poaceae_Pleioblastus_distichus leaf removed from tree...
# INFO: Poales_Poaceae_Sasa_veitchii leaf removed from tree...
# INFO: Poales_Poaceae_Phyllostachys_aureosulcata leaf removed from tree...
# INFO: Poales_Poaceae_Chimonobambusa_sichuanensis leaf removed from tree...
# INFO: Poales_Poaceae_Bashania_fargesii leaf removed from tree...
# INFO: Poales_Poaceae_Indocalamus_latifolius leaf removed from tree...
# INFO: Poales_Poaceae_Ferrocalamus_rimosivaginus leaf removed from tree...
# INFO: Poales_Poaceae_Yushania_anceps leaf removed from tree...
# INFO: Poales_Poaceae_Chimonocalamus_pallens leaf removed from tree...
# INFO: Poales_Poaceae_Sasaella_masamuneana leaf removed from tree...
# INFO: Poales_Poaceae_Semiarundinaria_fastuosa leaf removed from tree...
# INFO: Poales_Poaceae_Sinobambusa_tootsik leaf removed from tree...
# INFO: Poales_Poaceae_Bergbambos_tessellata leaf removed from tree...
# INFO: Poales_Poaceae_Kuruna_wightiana leaf removed from tree...
# INFO: Poales_Poaceae_Ekmanochloa_aristata leaf removed from tree...
# INFO: Poales_Poaceae_Mniochloa_pulchella leaf removed from tree...
# INFO: Poales_Poaceae_Piresiella_strephioides leaf removed from tree...
# INFO: Poales_Poaceae_Raddia_brasiliensis leaf removed from tree...
# INFO: Poales_Poaceae_Lithachne_pauciflora leaf removed from tree...
# INFO: Poales_Poaceae_Cryptochloa_strictiflora leaf removed from tree...
# INFO: Poales_Poaceae_Reitzia_smithii leaf removed from tree...
# INFO: Poales_Poaceae_Rehia_nervata leaf removed from tree...
# INFO: Poales_Poaceae_Parodiolyra_ramosissima leaf removed from tree...
# INFO: Poales_Poaceae_Pariana_radiciflora leaf removed from tree...
# INFO: Poales_Poaceae_Eremitis_sp. leaf removed from tree...
# INFO: Poales_Poaceae_Parianella_lanceolata leaf removed from tree...
# INFO: Poales_Poaceae_Maclurolyra_tecta leaf removed from tree...
# INFO: Poales_Poaceae_Rhynchoryza_subulata leaf removed from tree...
# INFO: Poales_Poaceae_Zizania_latifolia leaf removed from tree...
# INFO: Poales_Poaceae_Zizaniopsis_miliacea leaf removed from tree...
# INFO: Poales_Poaceae_Hygroryza_aristata leaf removed from tree...
# INFO: Poales_Poaceae_Potamophila_parviflora leaf removed from tree...
# INFO: Poales_Poaceae_Leersia_hexandra leaf removed from tree...
# INFO: Poales_Poaceae_Oryza_australiensis leaf removed from tree...
# INFO: Poales_Poaceae_Zotovia_thomsonii leaf removed from tree...
# INFO: Poales_Poaceae_Ehrharta_diplax leaf removed from tree...
# INFO: Poales_Poaceae_Tetrarrhena_laevis leaf removed from tree...
# INFO: Poales_Poaceae_Microlaena_stipoides leaf removed from tree...
# INFO: Poales_Poaceae_Puelia_coriacea leaf removed from tree...
# INFO: Poales_Poaceae_Leptaspis_zeylanica leaf removed from tree...
# INFO: Poales_Poaceae_Pharus_latifolius leaf removed from tree...
# INFO: Poales_Poaceae_Streptochaeta_spicata leaf removed from tree...
# INFO: Poales_Ecdeiocoleaceae_Ecdeiocolea_monostachya leaf removed from tree...
# INFO: Poales_Ecdeiocoleaceae_Georgeantha_hexandra leaf removed from tree...
# INFO: Poales_Joinvilleaceae_Joinvillea_ascendens leaf removed from tree...
# INFO: Poales_Flagellariaceae_Flagellaria_indica leaf removed from tree...
# INFO: Poales_Restionaceae_Chaetanthus_leptocarpoides leaf removed from tree...
# INFO: Poales_Restionaceae_Apodasmia_brownii leaf removed from tree...
# INFO: Poales_Restionaceae_Dapsilanthus_elatior leaf removed from tree...
# INFO: Poales_Restionaceae_Leptocarpus_tenax leaf removed from tree...
# INFO: Poales_Restionaceae_Hypolaena_fastigiata leaf removed from tree...
# INFO: Poales_Restionaceae_Alexgeorgea_nitens leaf removed from tree...
# INFO: Poales_Restionaceae_Taraxis_grossa leaf removed from tree...
# INFO: Poales_Restionaceae_Empodisma_minus leaf removed from tree...
# INFO: Poales_Restionaceae_Coleocarya_gracilis leaf removed from tree...
# INFO: Poales_Restionaceae_Desmocladus_fasciculatus leaf removed from tree...
# INFO: Poales_Restionaceae_Lepidobolus_preissianus leaf removed from tree...
# INFO: Poales_Restionaceae_Baloskion_tetraphyllum leaf removed from tree...
# INFO: Poales_Restionaceae_Tyrbastes_glaucescens leaf removed from tree...
# INFO: Poales_Restionaceae_Melanostachya_ustulata leaf removed from tree...
# INFO: Poales_Restionaceae_Dielsia_stenostachya leaf removed from tree...
# INFO: Poales_Restionaceae_Chordifex_stenandrus leaf removed from tree...
# INFO: Poales_Restionaceae_Tremulina_tremula leaf removed from tree...
# INFO: Poales_Restionaceae_Platychorda_applanata leaf removed from tree...
# INFO: Poales_Restionaceae_Loxocarya_cinerea leaf removed from tree...
# INFO: Poales_Restionaceae_Eurychorda_complanata leaf removed from tree...
# INFO: Poales_Restionaceae_Calorophus_elongatus leaf removed from tree...
# INFO: Poales_Restionaceae_Sporadanthus_strictus leaf removed from tree...
# INFO: Poales_Restionaceae_Lepyrodia_scariosa leaf removed from tree...
# INFO: Poales_Restionaceae_Askidiosperma_andreaeanum leaf removed from tree...
# INFO: Poales_Restionaceae_Platycaulos_mahonii leaf removed from tree...
# INFO: Poales_Restionaceae_Staberoha_cernua leaf removed from tree...
# INFO: Poales_Restionaceae_Elegia_tectorum leaf removed from tree...
# INFO: Poales_Restionaceae_Mastersiella_purpurea leaf removed from tree...
# INFO: Poales_Restionaceae_Cannomois_virgata leaf removed from tree...
# INFO: Poales_Restionaceae_Hypodiscus_rugosus leaf removed from tree...
# INFO: Poales_Restionaceae_Willdenowia_arescens leaf removed from tree...
# INFO: Poales_Restionaceae_Anthochortus_ecklonii leaf removed from tree...
# INFO: Poales_Restionaceae_Hydrophilus_rattrayi leaf removed from tree...
# INFO: Poales_Restionaceae_Centrolepis_fascicularis leaf removed from tree...
# INFO: Poales_Restionaceae_Gaimardia_fitzgeraldii leaf removed from tree...
# INFO: Poales_Restionaceae_Aphelia_brizula leaf removed from tree...
# INFO: Poales_Restionaceae_Hopkinsia_anoectocolea leaf removed from tree...
# INFO: Poales_Restionaceae_Lyginia_barbata leaf removed from tree...
# INFO: Poales_Restionaceae_Anarthria_prolifera leaf removed from tree...
# INFO: Poales_Xyridaceae_Xyris_aristata leaf removed from tree...
# INFO: Poales_Eriocaulaceae_Comanthera_paepalophylla leaf removed from tree...
# INFO: Poales_Eriocaulaceae_Rondonanthus_capillaceus leaf removed from tree...
# INFO: Poales_Eriocaulaceae_Syngonanthus_oblongus leaf removed from tree...
# INFO: Poales_Eriocaulaceae_Paepalanthus_pedunculatus leaf removed from tree...
# INFO: Poales_Eriocaulaceae_Eriocaulon_sp. leaf removed from tree...
# INFO: Poales_Mayacaceae_Mayaca_fluviatilis leaf removed from tree...
# INFO: Poales_Cyperaceae_Trichophorum_analecta leaf removed from tree...
# INFO: Poales_Cyperaceae_Carex_fraseriana leaf removed from tree...
# INFO: Poales_Cyperaceae_Sumatroscirpus_rupestris leaf removed from tree...
# INFO: Poales_Cyperaceae_Phylloscirpus_sp. leaf removed from tree...
# INFO: Poales_Cyperaceae_Scirpus_sp. leaf removed from tree...
# INFO: Poales_Cyperaceae_Rhodoscirpus_asper leaf removed from tree...
# INFO: Poales_Cyperaceae_Zameioscirpus_muticus leaf removed from tree...
# INFO: Poales_Cyperaceae_Amphiscirpus_nevadensis leaf removed from tree...
# INFO: Poales_Cyperaceae_Eriophorum_vaginatum leaf removed from tree...
# INFO: Poales_Cyperaceae_Calliscirpus_criniger leaf removed from tree...
# INFO: Poales_Cyperaceae_Khaosokia_caricoides leaf removed from tree...
# INFO: Poales_Cyperaceae_Dulichium_arundinaceum leaf removed from tree...
# INFO: Poales_Cyperaceae_Hellmuthia_membranacea leaf removed from tree...
# INFO: Poales_Cyperaceae_Isolepis_fluitans leaf removed from tree...
# INFO: Poales_Cyperaceae_Ficinia_truncata leaf removed from tree...
# INFO: Poales_Cyperaceae_Afroscirpoides_dioeca leaf removed from tree...
# INFO: Poales_Cyperaceae_Dracoscirpoides_falsa leaf removed from tree...
# INFO: Poales_Cyperaceae_Scirpoides_holoschoenus leaf removed from tree...
# INFO: Poales_Cyperaceae_Erioscirpus_comosus leaf removed from tree...
# INFO: Poales_Cyperaceae_Cyperus_rotundus leaf removed from tree...
# INFO: Poales_Cyperaceae_Schoenoplectiella_senegalensis leaf removed from tree...
# INFO: Poales_Cyperaceae_Schoenoplectus_corymbosus leaf removed from tree...
# INFO: Poales_Cyperaceae_Pseudoschoenus_inanis leaf removed from tree...
