# %% [markdown]
# #Creating the species list for query

# %%
import re
import pandas as pd

# Load the Newick tree file
tre_file_path = r'C:\Users\HebraT\Desktop\08_Data_Of_Plants\global_tree_brlen_pruned_renamed.tre'

# Read the Newick tree as plain text
with open(tre_file_path, 'r') as file:
    tree_data = file.read()

# Define a regular expression to capture Order, Family, Genus, and Species
pattern = r"([A-Za-z]+)_([A-Za-z]+)_([A-Za-z]+)_([A-Za-z]+)"

# Find all matches of the taxonomic strings in the Newick tree
matches = re.findall(pattern, tree_data)

# Convert the matches into a DataFrame with separate columns for each taxonomic rank
df_taxonomy = pd.DataFrame(matches, columns=["Order", "Family", "Genus", "Species"])

# Save the resulting DataFrame as a CSV file
output_csv_path = r'C:\Users\HebraT\Desktop\08_Data_Of_Plants\Extracted_species_tree.csv'
df_taxonomy.to_csv(output_csv_path, index=False)

print(f"Taxonomic ranks extracted and saved to: {output_csv_path}")
# Out:
# Taxonomic ranks extracted and saved to: C:\Users\HebraT\Desktop\08_Data_Of_Plants\Extracted_species_tree.csv

# %% [markdown]
# #Retrieving ALL plants compounds

# %%
import requests
import pandas as pd
import os
import time
from concurrent.futures import ThreadPoolExecutor, as_completed

# SPARQL query template
sparql_query_template = """
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX p: <http://www.wikidata.org/prop/>
PREFIX ps: <http://www.wikidata.org/prop/statement/>
PREFIX pr: <http://www.wikidata.org/prop/reference/>
PREFIX prov: <http://www.w3.org/ns/prov#>

#title: Available referenced structure-organism pairs on Wikidata for a specified genus (using genus name)
SELECT DISTINCT ?structure ?structure_inchikey ?structure_smiles ?taxon ?taxon_name ?reference ?reference_doi WHERE {{
    # Find the genus QID by its scientific name
    # ?genus wdt:P225 "{genus_name}".

    # Query for all descendant taxa (species) within the genus
    # ?taxon wdt:P171* ?genus.                      # Include all descendant taxa (species)
    # ?structure wdt:P235 ?structure_inchikey;      # Get the InChIKey of the structure
               wdt:P233 ?structure_smiles;        # Get the SMILES of the structure
               p:P703 [                           # Statement found in taxon
               ps:P703 ?taxon;                    # Link to taxon
               (prov:wasDerivedFrom/pr:P248) ?reference ].  # Get the reference
    # ?taxon wdt:P225 ?taxon_name.                  # Get the taxon scientific name
    # ?reference wdt:P356 ?reference_doi.           # Get the reference DOI
}}

"""

def run_sparql_query(genus_name, max_retries=50, backoff_factor=1):
    endpoint_url = "https://query.wikidata.org/sparql"
    query = sparql_query_template.format(genus_name=genus_name)
    
    retries = 0
    wait_time = 1  # Start with 1 second wait time

    while retries < max_retries:
        response = requests.get(endpoint_url, params={'query': query, 'format': 'json'})
        
        if response.status_code == 200:
            data = response.json()
            return data["results"]["bindings"]
        elif response.status_code == 429:
            # Handle rate limiting (429 Too Many Requests)
            print(f"Rate limit exceeded for genus {genus_name}. Retrying in {wait_time} seconds...")
            time.sleep(wait_time)
            retries += 1
            wait_time *= backoff_factor  # Exponential backoff
        else:
            print(f"Error querying genus {genus_name}: {response.status_code}")
            break
    
    print(f"Failed to retrieve data for genus {genus_name} after {max_retries} retries.")
    return None

def save_results_to_csv(genus_name, results, output_folder):
    # Create a DataFrame to store the results
    rows = []
    for result in results:
        row = {
            "structure": result.get("structure", {}).get("value", ""),
            "structure_inchikey": result.get("structure_inchikey", {}).get("value", ""),
            "structure_smiles": result.get("structure_smiles", {}).get("value", ""),
            "taxon": result.get("taxon", {}).get("value", ""),
            "taxon_name": result.get("taxon_name", {}).get("value", ""),
            "reference": result.get("reference", {}).get("value", ""),
            "reference_doi": result.get("reference_doi", {}).get("value", "")
        }
        rows.append(row)
    
    # Create a DataFrame from the rows
    df = pd.DataFrame(rows)
    
    # Save the DataFrame to a CSV file named after the genus
    file_path = os.path.join(output_folder, f"{genus_name}.csv")
    df.to_csv(file_path, index=False)
    print(f"Saved results for genus {genus_name} to {file_path}")

def process_genus(genus_name, output_folder):
    print(f"Processing genus {genus_name}...")
    results = run_sparql_query(genus_name)
    if results:
        save_results_to_csv(genus_name, results, output_folder)
    else:
        print(f"No results for genus {genus_name}")

def process_genus_csv_multithreaded(input_csv, output_folder, max_workers=5):
    # Read the genus names from the CSV file
    df = pd.read_csv(input_csv)
    if 'Genus' not in df.columns:
        print("Error: 'genus' column not found in the CSV file.")
        return
    
    # Ensure the output folder exists
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Process each genus using multithreading
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = []
        for idx, row in df.iterrows():
            genus_name = row['Genus']
            futures.append(executor.submit(process_genus, genus_name, output_folder))
        
        # Track progress
        for future in as_completed(futures):
            future.result()  # Ensures exceptions are raised if any

# Usage example:
process_genus_csv_multithreaded(r'C:\Users\HebraT\Desktop\08_Data_Of_Plants\Extracted_species_tree.csv', r'C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants', max_workers=2)
# Out:
# Processing genus Neostapfia...
# Processing genus Orcuttia...
# No results for genus OrcuttiaNo results for genus Neostapfia
# Processing genus Orinus...
#
# Processing genus Tridentopsis...
# No results for genus Orinus
# Processing genus Gouinia...
# No results for genus Tridentopsis
# Processing genus Sphenopholis...
# No results for genus Gouinia
# Processing genus Triplasiella...
# No results for genus Sphenopholis
# Processing genus Vaseyochloa...
# No results for genus Triplasiella
# Processing genus Craspedorhachis...
# No results for genus Vaseyochloa
# Processing genus Farrago...
# No results for genus Farrago
# Processing genus Perotis...
# No results for genus Craspedorhachis
# Processing genus Mosdenia...
# Rate limit exceeded for genus Perotis. Retrying in 1 seconds...
# Rate limit exceeded for genus Mosdenia. Retrying in 1 seconds...
# Rate limit exceeded for genus Mosdenia. Retrying in 1 seconds...
# No results for genus Perotis
# Processing genus Trichoneura...
# Rate limit exceeded for genus Trichoneura. Retrying in 1 seconds...
# No results for genus Mosdenia
# Processing genus Coleanthus...
# Rate limit exceeded for genus Trichoneura. Retrying in 1 seconds...
# Rate limit exceeded for genus Coleanthus. Retrying in 1 seconds...
# Rate limit exceeded for genus Coleanthus. Retrying in 1 seconds...
# No results for genus Trichoneura
# Processing genus Tetrachaete...
# Rate limit exceeded for genus Tetrachaete. Retrying in 1 seconds...
# No results for genus Coleanthus
# Processing genus Dignathia...
# Rate limit exceeded for genus Dignathia. Retrying in 1 seconds...
# Rate limit exceeded for genus Tetrachaete. Retrying in 1 seconds...
# Rate limit exceeded for genus Dignathia. Retrying in 1 seconds...
# No results for genus Tetrachaete
# Processing genus Hubbardochloa...
# Rate limit exceeded for genus Hubbardochloa. Retrying in 1 seconds...
# No results for genus Dignathia
# Processing genus Lophacme...
# Rate limit exceeded for genus Hubbardochloa. Retrying in 1 seconds...
# Rate limit exceeded for genus
C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants\Kadsura.csv
# Processing genus Schisandra...
# Rate limit exceeded for genus Schisandra. Retrying in 1 seconds...
# Saved results for genus Ceratophyllum to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants\Ceratophyllum.csv
# Processing genus Illicium...
# Rate limit exceeded for genus Illicium. Retrying in 1 seconds...
# Rate limit exceeded for genus Schisandra. Retrying in 1 seconds...
# Rate limit exceeded for genus Schisandra. Retrying in 1 seconds...
# Saved results for genus Illicium to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants\Illicium.csv
# Processing genus Trimenia...
# Rate limit exceeded for genus Trimenia. Retrying in 1 seconds...
# Rate limit exceeded for genus Trimenia. Retrying in 1 seconds...
# Saved results for genus Schisandra to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants\Schisandra.csv
# Processing genus Austrobaileya...
# Rate limit exceeded for genus Austrobaileya. Retrying in 1 seconds...
# Saved results for genus Trimenia to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants\Trimenia.csv
# Processing genus Nuphar...
# Rate limit exceeded for genus Nuphar. Retrying in 1 seconds...
# Rate limit exceeded for genus Austrobaileya. Retrying in 1 seconds...
# Rate limit exceeded for genus Austrobaileya. Retrying in 1 seconds...
# Saved results for genus Nuphar to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants\Nuphar.csv
# Processing genus Euryale...
# Rate limit exceeded for genus Euryale. Retrying in 1 seconds...
# Saved results for genus Austrobaileya to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants\Austrobaileya.csv
# Processing genus Victoria...
# Rate limit exceeded for genus Victoria. Retrying in 1 seconds...
# Rate limit exceeded for genus Euryale. Retrying in 1 seconds...
# Rate limit exceeded for genus Euryale. Retrying in 1 seconds...
# Saved results for genus Victoria to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants\Victoria.csv
# Processing genus Nymphaea...
# Rate limit exceeded for genus Nymphaea. Retrying in 1 seconds...
# Rate limit exceeded for genus Nymphaea. Retrying in 1 seconds...
# Saved results for genus Euryale to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants\Euryale.csv
# Processing genus Barclaya...
# Rate limit exceeded for genus Barclaya. Retrying in 1 seconds...
# Rate limit exceeded for genus Barclaya. Retrying in 1 seconds...
# Saved results for genus Nymphaea to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants\Nymphaea.csv
# Processing genus Brasenia...
# Rate limit exceeded for genus Brasenia. Retrying in 1 seconds...
# No results for genus Barclaya
# Processing genus Cabomba...
# Rate limit exceeded for genus Cabomba. Retrying in 1 seconds...
# Rate limit exceeded for genus Brasenia. Retrying in 1 seconds...
# Rate limit exceeded for genus Brasenia. Retrying in 1 seconds...
# No results for genus Cabomba
# Processing genus Trithuria...
# Rate limit exceeded for genus Trithuria. Retrying in 1 seconds...
# Saved results for genus Brasenia to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants\Brasenia.csv
# Processing genus Amborella...
# Rate limit exceeded for genus Amborella. Retrying in 1 seconds...
# Rate limit exceeded for genus Trithuria. Retrying in 1 seconds...
# Rate limit exceeded for genus Trithuria. Retrying in 1 seconds...
# Saved results for genus Amborella to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants\Amborella.csv
# No results for genus Trithuria
# c:\Users\HebraT\anaconda3\lib\ast.py:50: RuntimeWarning: coroutine 'query_taxon_names_async' was never awaited
#   return compile(source, filename, mode, flags,
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [14], in <cell line: 113>()
#     110             future.result()  # Ensures exceptions are raised if any
#     112 # Usage example:
# --> 113 process_genus_csv_multithreaded(r'C:\Users\HebraT\Desktop\08_Data_Of_Plants\Extracted_species_tree.csv', r'C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants', max_workers=2)
#
# Input In [14], in process_genus_csv_multithreaded(input_csv, output_folder, max_workers)
#     108 # Track progress
#     109 for future in as_completed(futures):
# --> 110     future.result()
#
# File c:\Users\HebraT\anaconda3\lib\concurrent\futures\_base.py:439, in Future.result(self, timeout)
#     437     raise CancelledError()
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\HebraT\anaconda3\lib\concurrent\futures\_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File c:\Users\HebraT\anaconda3\lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# Input In [14], in process_genus(genus_name, output_folder)
#      84 results = run_sparql_query(genus_name)
#      85 if results:
# ---> 86     save_results_to_csv(genus_name, results, output_folder)
#      87 else:
#      88     print(f"No results for genus {genus_name}")
#
# Input In [14], in save_results_to_csv(genus_name, results, output_folder)
#      77 # Save the DataFrame to a CSV file named after the genus
#      78 file_path = os.path.join(output_folder, f"{genus_name}.csv")
# ---> 79 df.to_csv(file_path, index=False)
#      80 print(f"Saved results for genus {genus_name} to {file_path}")
#
# File c:\Users\HebraT\anaconda3\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
#    3556     errors=errors,
#    3557     compression=compression,
#    3558     quoting=quoting,
#    3559     columns=columns,
#    3560     index_label=index_label,
#    3561     mode=mode,
#    3562     chunksize=chunksize,
#    3563     quotechar=quotechar,
#    3564     date_format=date_format,
#    3565     doublequote=doublequote,
#    3566     escapechar=escapechar,
#    3567     storage_options=storage_options,
#    3568 )
#
# File c:\Users\HebraT\anaconda3\lib\site-packages\pandas\io\formats\format.py:1180, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1159     created_buffer = False
#    1161 csv_formatter = CSVFormatter(
#    1162     path_or_buf=path_or_buf,
#    1163     line_terminator=line_terminator,
#    (...)
#    1178     formatter=self.fmt,
#    1179 )
# -> 1180 csv_formatter.save()
#    1182 if created_buffer:
#    1183     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\HebraT\anaconda3\lib\site-packages\pandas\io\formats\csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.line_terminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File c:\Users\HebraT\anaconda3\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\HebraT\\Desktop\\08_Data_Of_Plants\\Isolated_Cpd_Plants\\Abeliophyllum.csv'

# %% [markdown]
# Cleaning non plant metabolites

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Draw
from IPython.display import display, HTML
from io import BytesIO
import base64

# Function to convert molecule to an image and then to base64
def mol_to_img(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles)
        if mol is None:
            return "Invalid SMILES"
        img = Draw.MolToImage(mol)
        
        # Convert the image to a PNG and then to base64
        buffered = BytesIO()
        img.save(buffered, format="PNG")
        img_str = base64.b64encode(buffered.getvalue()).decode("utf-8")
        
        # Return HTML image tag with base64-encoded PNG
        return f'<img src="data:image/png;base64,{img_str}" />'
    except:
        return "Error generating image"

# Load your CSV data
csv_file_path = r'C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants\Euphorbia.csv'  # Update with your local file path
df = pd.read_csv(csv_file_path)

# Apply the image generation to the DataFrame
df['Molecule Image'] = df['structure_smiles'].apply(mol_to_img)

# Display the DataFrame as an HTML table
def display_table(df):
    return HTML(df.to_html(escape=False))

# Display the table in your notebook
display(display_table(df[['taxon_name', 'Molecule Image']]))

# %%
import os
import pandas as pd
import requests
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor

# Folder path containing the CSV files
folder_path = r'C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants'

# File to save non-plant entries
non_plant_file = r'C:\Users\HebraT\Desktop\08_Data_Of_Plants\non_plants3.csv'

# Cache to store results of taxon queries
taxon_cache = {}

# GBIF API base URL for name backbone searches
GBIF_API_URL = "https://api.gbif.org/v1/species/match?name="

# Function to check if a taxon is a plant using requests
def fetch_taxon(taxon_name):
    if taxon_name in taxon_cache:
        return taxon_name, taxon_cache[taxon_name]
    
    try:
        response = requests.get(GBIF_API_URL + taxon_name)
        if response.status_code == 200:
            result = response.json()
            is_plant_taxon = 'kingdom' in result and result['kingdom'].lower() == 'plantae'
            taxon_cache[taxon_name] = is_plant_taxon
            return taxon_name, is_plant_taxon
    except requests.RequestException:
        pass
    
    # If the request fails, mark it as not a plant
    taxon_cache[taxon_name] = False
    return taxon_name, False

# Function to query taxon names in parallel using threading
def query_taxon_names_parallel(taxon_name_list, batch_size=100):
    all_results = []
    with ThreadPoolExecutor(max_workers=8) as executor:
        # Process taxon names in batches
        taxon_batches = [taxon_name_list[i:i + batch_size] for i in range(0, len(taxon_name_list), batch_size)]
        
        for batch in tqdm(taxon_batches, desc="Querying taxon names in batches"):
            results = list(executor.map(fetch_taxon, batch))
            all_results.extend(results)
    
    # Store results in cache
    for taxon_name, is_plant in all_results:
        taxon_cache[taxon_name] = is_plant

# Step 1: Collect all unique taxon names from all files
def collect_all_taxon_names():
    all_taxon_names = set()
    csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]
    
    for file in tqdm(csv_files, desc="Collecting taxon names"):
        file_path = os.path.join(folder_path, file)
        df = pd.read_csv(file_path)
        all_taxon_names.update(df['taxon_name'].unique())
    
    return list(all_taxon_names)

# Step 3: Update each file by removing non-plant entries
def update_files():
    all_non_plants = []
    csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]
    
    for file in tqdm(csv_files, desc="Updating files"):
        file_path = os.path.join(folder_path, file)
        df = pd.read_csv(file_path)
        
        # Apply the cached results
        df['is_plant'] = df['taxon_name'].map(taxon_cache)
        
        # Collect non-plant entries
        non_plants = df[~df['is_plant']]
        for _, row in non_plants.iterrows():
            all_non_plants.append({'Original_File': file, 'Taxon': row['taxon_name']})
        
        # Remove non-plant entries from the original file
        df_plants_only = df[df['is_plant']]
        df_plants_only.drop(columns=['is_plant'], inplace=True)
        df_plants_only.to_csv(file_path, index=False)
    
    # Save all non-plant entries to a new CSV file
    non_plant_df = pd.DataFrame(all_non_plants)
    non_plant_df.to_csv(non_plant_file, index=False)

    print(f"Processing completed. Non-plant entries saved to {non_plant_file}")

if __name__ == '__main__':
    # Step 1: Collect all unique taxon names
    taxon_name_list = collect_all_taxon_names()

    # Step 2: Query all taxon names using parallel processing
    query_taxon_names_parallel(taxon_name_list)

    # Step 3: Update all files and remove non-plant entries
    update_files()
# Out:
# Collecting taxon names: 100%|██████████| 3456/3456 [00:09<00:00, 353.25it/s]
# Querying taxon names in batches: 100%|██████████| 233/233 [07:56<00:00,  2.05s/it]
# Updating files:   0%|          | 0/3456 [00:00<?, ?it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:   0%|          | 8/3456 [00:00<00:53, 64.02it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:   0%|          | 15/3456 [00:00<00:53, 64.33it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:   1%|          | 32/3456 [00:00<00:49, 68.83it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:   1%|          | 39/3456 [00:00<00:51, 66.74it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:   2%|▏         | 54/3456 [00:00<00:49, 68.53it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:   3%|▎         | 87/3456 [00:01<00:44, 75.02it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:   4%|▍         | 134/3456 [00:02<01:00, 54.77it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:   4%|▍         | 149/3456 [00:02<00:54, 61.11it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:   5%|▍         | 165/3456 [00:02<00:48, 67.39it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:   6%|▌         | 198/3456 [00:03<00:43, 75.65it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:   6%|▌         | 215/3456 [00:03<00:43, 75.02it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:   7%|▋         | 231/3456 [00:03<00:46, 68.87it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:   7%|▋         | 249/3456 [00:03<00:41, 76.56it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:   7%|▋         | 257/3456 [00:03<00:44, 71.91it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:   9%|▉         | 313/3456 [00:05<01:05, 47.71it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:   9%|▉         | 318/3456 [00:05<01:18, 39.92it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:  10%|▉         | 342/3456 [00:05<01:04, 48.19it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:  12%|█▏        | 398/3456 [00:06<00:43, 70.85it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:  12%|█▏        | 406/3456 [00:06<00:42, 71.03it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:  12%|█▏        | 423/3456 [00:07<00:48, 62.95it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:  13%|█▎        | 456/3456 [00:07<00:41, 72.02it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:  15%|█▌        | 525/3456 [00:08<00:55, 53.25it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:
/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:  87%|████████▋ | 3003/3456 [00:53<00:08, 53.53it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:  89%|████████▉ | 3078/3456 [00:54<00:05, 69.98it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:  89%|████████▉ | 3086/3456 [00:55<00:06, 61.13it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:  92%|█████████▏| 3165/3456 [00:56<00:05, 52.30it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:  93%|█████████▎| 3203/3456 [00:57<00:05, 50.08it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:  94%|█████████▍| 3243/3456 [00:58<00:02, 71.92it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:  94%|█████████▍| 3259/3456 [00:58<00:02, 68.32it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:  95%|█████████▍| 3281/3456 [00:58<00:02, 65.47it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:  97%|█████████▋| 3343/3456 [00:59<00:02, 44.13it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:  97%|█████████▋| 3364/3456 [01:00<00:02, 45.51it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files:  99%|█████████▉| 3434/3456 [01:01<00:00, 68.68it/s]C:\Users\HebraT\AppData\Local\Temp\ipykernel_29672\121974406.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plants_only.drop(columns=['is_plant'], inplace=True)
# Updating files: 100%|██████████| 3456/3456 [01:01<00:00, 55.76it/s]
# Processing completed. Non-plant entries saved to C:\Users\HebraT\Desktop\08_Data_Of_Plants\non_plants3.csv

# %%
import os
import shutil
import pandas as pd

# Load the CSV file
file_path = r'C:\Users\HebraT\Desktop\08_Data_Of_Plants\non_plants3.csv'
data = pd.read_csv(file_path)

# Directories to search and copy files
source_folder = r'C:\Users\HebraT\Desktop\08_Data_Of_Plants\04_Isolated_Cpd_Plants'
destination_folder = r'C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants'

# Create the destination folder if it doesn't exist
os.makedirs(destination_folder, exist_ok=True)

# Filter rows where the 'Plant' column is marked as 'Plant'
plant_rows = data[data['Plant'] == 'Plant']

# Loop through the filtered rows
for index, row in plant_rows.iterrows():
    original_file = row['Original_File']
    
    # Construct the full file path in the source directory
    source_file = os.path.join(source_folder, original_file)
    
    # Check if the file exists in the source folder
    if os.path.isfile(source_file):
        # Construct the destination file path
        destination_file = os.path.join(destination_folder, original_file)
        
        # Copy the file to the destination folder
        shutil.copy(source_file, destination_file)
        print(f"Copied {original_file} to {destination_folder}")
    else:
        print(f"File {original_file} not found in {source_folder}")
# Out:
# Copied Abrus.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Acanthus.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Acourtia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Actaea.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Adenophora.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Aglaia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Aglaia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Aglaia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Alpinia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Amaranthus.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Amorpha.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Angelica.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Annona.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Antimima.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Apium.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Aquilaria.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Arachis.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Aster.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Astraea.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Astridia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Avena.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Beta.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Betula.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Beyeria.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Bidens.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Blepharis.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Bougainvillea.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Calendula.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Callicarpa.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Calophyllum.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Cameraria.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Ceiba.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Cerbera.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Citrus.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Clusia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Colocasia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Colubrina.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Corydalis.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Coscinium.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Cotyledon.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Crassula.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Cucumis.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Cucurbita.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Cydonia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Cymbidium.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Daphne.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Daphne.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Dendrobium.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Digitaria.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Diplotaxis.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Dracaena.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Drymaria.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Duboisia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Echinops.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Eclipta.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Elephantopus.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Epiphyllum.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Eremophila.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Esenbeckia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Euodia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Euryops.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Ficus.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Ficus.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Flemingia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Fritillaria.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Fuchsia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Fumaria.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Genista.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Gmelina.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Grahamia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Haplophyllum.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Hedera.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Heterotheca.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Homalium.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Houttuynia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Hubertia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Iris.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Ismene.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Isodon.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Iva.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Kaempferia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Kleinia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Leschenaultia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Lindera.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Linnaea.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Lonicera.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Lotus.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Lychnophora.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Melaleuca.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Melia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Millettia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Morus.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Myristica.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Olea.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Oncidium.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Ormosia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Paliurus.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Pentzia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Perezia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Perilla.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Periploca.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Phalaenopsis.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Phaseolus.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Phyllanthus.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Physalis.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Pieris.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Pieris.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Pieris.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Plumbago.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Polypogon.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Psidium.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Pterocaulon.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Rehmannia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Rhaphiolepis.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Rhinacanthus.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Rhynchosia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Ruschia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Salacia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Salix.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Salix.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Saussurea.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Scoparia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Scoparia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Scopolia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Semenovia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Setaria.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Silene.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Smilax.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Stilbe.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Streblus.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Tephrosia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Thymus.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Tribulus.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Trichodiadema.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Trifolium.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Trigonella.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Tristania.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Tritonia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Vatica.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Viola.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Virgilia.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants
# Copied Zea.csv to C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants

# %%
import os
import pandas as pd

# Specify the folder path where your .csv files are located
folder_path = r'C:\Users\HebraT\Desktop\08_Data_Of_Plants\Isolated_Cpd_Plants'

# Load the Extracted_species_tree.csv file
extracted_species_tree_path = r'C:\Users\HebraT\Desktop\08_Data_Of_Plants\Extracted_species_tree.csv'
extracted_species_tree = pd.read_csv(extracted_species_tree_path)

# Ensure the Genus column is in lowercase for case-insensitive matching
extracted_species_tree['Genus'] = extracted_species_tree['Genus'].str.lower()

# Create a new column in extracted_species_tree to store the reported count
extracted_species_tree['Reported_Cpd'] = 0

# Iterate over each .csv file in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(folder_path, file_name)
        
        # Count the number of lines excluding the header
        with open(file_path, 'r') as f:
            line_count = sum(1 for line in f) - 1  # Subtract 1 to exclude the header
        
        # Get the file name without extension
        genus_name = os.path.splitext(file_name)[0].lower()

        # Check if the file name (as genus) matches any in the Genus column
        if genus_name in extracted_species_tree['Genus'].values:
            # Update the Reported_Cpd column with the line count for the matching genus
            extracted_species_tree.loc[extracted_species_tree['Genus'] == genus_name, 'Reported_Cpd'] = line_count

# Save the updated extracted_species_tree.csv file
updated_csv_path = r'C:\Users\HebraT\Desktop\08_Data_Of_Plants\00_Species_extraction\Extracted_species_tree_isolated_wikidata.csv'
extracted_species_tree.to_csv(updated_csv_path, index=False)

print("Updated Extracted_species_tree.csv saved successfully!")
# Out:
# Updated Extracted_species_tree.csv saved successfully!

# %%
import csv

# Path to the CSV file
csv_file = r'C:\Users\HebraT\Desktop\08_Data_Of_Plants\00_Species_extraction\Extracted_species_tree_isolated_wikidata.csv'

# Set to store all unique IDs
all_ids = set()

# Read the CSV file and extract the 'Full_string' and 'Reported_Cpd' columns
with open(csv_file, newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f, delimiter=',')
    for row in reader:
        full_string = row.get('Full_string', '').strip()
        reported_cpd = row.get('Reported_Cpd', '').strip()
        
        # Ensure both fields are not empty
        if full_string != '' and reported_cpd != '':
            all_ids.add((full_string, reported_cpd))

# Path to output annotation file
output_file = r'C:\Users\HebraT\Desktop\08_Data_Of_Plants\00_Species_extraction\Isolated_cpd_annotation.txt'

# Write headers and data to the annotation file
with open(output_file, 'w', newline='', encoding='utf-8') as f:
    f.write('DATASET_SIMPLEBAR\n')
    f.write('SEPARATOR COMMA\n')
    f.write('DATASET_LABEL,Isolated_cpds\n')
    f.write('COLOR,#000000\n')
    f.write('DATA\n')
    
    # Write each unique pair of Full_string and Reported_Cpd
    for full_string, reported_cpd in all_ids:
        f.write(f'{full_string},{reported_cpd}\n')

print("Annotation file has been successfully created.")
# Out:
# Annotation file has been successfully created.

# %%
import re
from collections import defaultdict

# File paths
input_file_path = 'path_to_your_tree_file.tre'
output_file_path = 'path_to_output_file.txt'

# Regular expression to capture strings in the format Order_Family_Genus_Specie
pattern = re.compile(r'([A-Za-z]+_[A-Za-z]+_[A-Za-z]+_[A-Za-z]+)')

# Dictionary to store the first and last occurrences of each order
order_occurrences = defaultdict(list)

# Read the tree file
with open(input_file_path, 'r') as file:
    tree_data = file.readlines()

# Search for the taxonomic strings and group them by order
for line in tree_data:
    matches = pattern.findall(line)
    for match in matches:
        order = match.split("_")[0]  # Extract the order part of the string
        order_occurrences[order].append(match)

# Prepare the output with alternating colors and range format
output_data = []
color1 = "#f4cccc"
color2 = "#cfe2f3"

for i, (order, taxa_list) in enumerate(order_occurrences.items()):
    first_occurrence = taxa_list[0]  # First occurrence of the order
    last_occurrence = taxa_list[-1]  # Last occurrence of the order
    color = color1 if i % 2 == 0 else color2  # Alternate between color1 and color2
    
    # Format the data with comma separators
    formatted_line = f"{first_occurrence},{last_occurrence},range,{color},{order}"
    output_data.append(formatted_line)

# Prepare the header and dataset information
header = [
    "TREE_COLORS",
    "SEPARATOR COMMA",
    "DATA"
]

# Combine header and data
final_output = "\n".join(header + output_data)

# Write the output to a file
with open(output_file_path, 'w') as output_file:
    output_file.write(final_output)

print(f"Output file written to {output_file_path}")

# %% [markdown]
# Replacing wrong ID buy correct ones

# %%
# Step 1: Read the incomplete-to-complete ID mappings
mapping_file = r"C:\Users\HebraT\Desktop\08_Data_Of_Plants\Problematic_ID.txt"
incomplete_to_complete = {}

with open(mapping_file, "r") as f:
    for line in f:
        incomplete_id, complete_id = line.strip().split(',')
        incomplete_to_complete[incomplete_id] = complete_id

# Step 2: Read the file containing strings with incomplete IDs
input_file = r"C:\Users\HebraT\Desktop\08_Data_Of_Plants\05_Tree_annotation\01_Isolated_cpd_annotation.txt"
output_file = r"C:\Users\HebraT\Desktop\08_Data_Of_Plants\05_Tree_annotation\01_Isolated_cpd_annotation.txt"

with open(input_file, "r") as f:
    content = f.readlines()

# Step 3: Replace incomplete IDs with complete IDs
updated_content = []
for line in content:
    for incomplete_id, complete_id in incomplete_to_complete.items():
        if incomplete_id in line:
            line = line.replace(incomplete_id, complete_id)
    updated_content.append(line)

# Step 4: Write the updated content to a new file (or overwrite the original file)
with open(output_file, "w") as f:
    f.writelines(updated_content)

print(f"Updated file saved as {output_file}")
# Out:
# Updated file saved as C:\Users\HebraT\Desktop\08_Data_Of_Plants\05_Tree_annotation\01_Isolated_cpd_annotation.txt

# %%
from pygbif import species

def is_plant(genus_name):
    # Query GBIF for genus information
    search_result = species.name_backbone(name=genus_name)
    
    if 'kingdom' in search_result and search_result['kingdom'].lower() == 'plantae':
        return True  # It's a plant genus
    return False  # Not a plant genus or no data found

# Example usage
genus = "Abroma augustum"
if is_plant(genus):
    print(f"{genus} is a plant genus.")
else:
    print(f"{genus} is not a plant genus.")
# Out:
# Abroma augustum is a plant genus.
